# %% [markdown]
# # Assignment 2
# Basic Aerodynamics
# s134166 Aleksander Andersen
# s000000 Martin Simon

# %%
# Modules
import numpy as np
import pylab
import matplotlib.pyplot as plt
# %matplotlib inline

deg= u'\N{DEGREE SIGN}'
deg
# Out:
# u'\xb0'

# %% [markdown]
# ### Part 1 - Planar/rectangular
# Employ the fundamental equation of Prandtl’s lifting-line theory to determine the distribution of induced angle of attack along the wing for different aspect ratios, AR, and angles of attack, AOA. Plot the distributions for AR = 4, 6, 8, 10 and AOA = 0°, 5°, 10°. Compute the corresponding induced drag and lift coefficients.

# %% [markdown]
# The fundamental equation of Prandtl's lifting line theory is
# $$ \alpha(y_0) = \dfrac{\Gamma(y_0)}{\pi V_{\infty}c(y_0)}
# + \alpha_{L=0}(y_0) + \dfrac{1}{4\pi V_{\infty}} \int_{-b/2}^{b/2} \dfrac{(d\Gamma/dy)dy}{y_0-y}$$
# where
# $y$: lifting line axis
# $b$: wing span ( $ \pm b/2$)

# %% [markdown]
# $\text{AR} =b^2/S$
# $S$: area (for rectangular plate)

# %% [markdown]
# $S=cb \Rightarrow \text{AR}=b/c$

# %% [markdown]
# Eq. 8.44a rewritten with $A_R= b/c$
# $ \sum_{n=1}^\infty A_n \sin{n\theta}
# \left( \dfrac{4 \, A_R(\theta)}{m_0(\theta)} + \dfrac{n}{\sin{\theta}}
# \right) = \alpha (\theta) - \alpha_{L0}(\theta)$
# Corresponds to matrix equation
# $Ax=b$

# %%
def planarWing(AR, alphad):
    m0 = 0.11*180/np.pi
    alpha = alphad *np.pi/180
    alpha_L0 = -4 *np.pi/180
    
    # number of sums 
    n_max = 20 # number of terms in sum
    n = np.linspace(1,n_max,n_max).astype(int)
    
    # number of equations (theta values)
    nEQ = n_max
    nEQ2 = int(nEQ+2)
    theta = np.linspace(np.pi/nEQ, np.pi-np.pi/nEQ, nEQ)
    #theta= theta[1: nEQ2-1]
    
    M = np.empty((nEQ, n_max)) # Empty matrix (100x100)
    b = np.empty( nEQ )
    for i in range(nEQ):
        for j in range(n_max):
            # Calculate coefficients
            M[i,j] = np.sin(n[j]*theta[i]) *(4*AR/m0 + n[j]/np.sin(theta[i]))
        b[i] = alpha-alpha_L0 # RHS
    # Solve system
    An = np.linalg.solve(M,b)
    
    # Calculate induced angles
    alpha_i = np.empty(nEQ) # empty
    for i in range(nEQ):
        alpha_i[i] = sum(n*An*np.sin(n*theta[i])/np.sin(theta[i]))
    
    # Induced lift and drag
    C_L = np.pi*AR * An[0] # eq. (8.51)
    C_D = np.pi*AR * np.sum(n*An**2) # eq. (8.52)
    return n, theta, C_L, C_D, alpha_i, An

# %%
def WingPlotPlanar(AR,alphad):

    for i in range(0,len(alphad)):
        plt.figure()
        for j in range(0,len(AR)):
            n,theta,Cl,Cd,ai,An = planarWing(AR[j], alphad[i])
            plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}'.format(AR[j], alphad[i]))
            
        plt.title('Induced Angle of Attack')
        plt.xlabel('theta [deg]')
        plt.ylabel('alpha_i [deg]')
        plt.grid()
        plt.legend()
        #pylab.savefig('planar.png', bbox_inches='tight')
        name = 'planar'+str(alphad[i]) +'.png'
        plt.savefig(name)
    plt.figure()
    
    
    for i in range(0,len(alphad)):
        for j in range(0,len(AR)):
            n, theta, Cl, Cd, ai, An = planarWing(AR[j], alphad[i])
            plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR[j], alphad[i]))

        plt.title('Induced Angle of Attack for all AoA')
        plt.xlabel('theta [deg]')
        plt.ylabel('alpha_i [deg]')
        plt.grid()
        #plt.legend()
        name = 'AllInducedPlanar.png'
        plt.savefig(name)
    #plt.legend()

# %%
AR=[4, 6, 8, 10]
alphad=[0, 5, 10, 15]

WingPlotPlanar(AR,alphad)

# %%
## PLOTTING RESULTS FOR 2.1

plt.figure()
AR, alphad = 4, 0
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 6, 0
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 8, 0
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 10, 0
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

plt.title('Induced Angle of Attack')
plt.xlabel('theta [*]')
plt.ylabel('alpha_i [*]')
plt.grid()
plt.legend()
# Out:
# AR // AOA :: 4 // 0 deg
# CDi: 0.0065
# Cl: 0.2818
#
# AR // AOA :: 6 // 0 deg
# CDi: 0.0056
# Cl: 0.3170
#
# AR // AOA :: 8 // 0 deg
# CDi: 0.0049
# Cl: 0.3386
#
# AR // AOA :: 10 // 0 deg
# CDi: 0.0043
# Cl: 0.3532

# %%
plt.figure()
AR, alphad = 4, 5
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 6, 5
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 8, 5
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 10, 5
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

plt.title('Induced Angle of Attack')
plt.xlabel('theta [*]')
plt.ylabel('alpha_i [*]')
plt.grid()
plt.legend()
# Out:
# AR // AOA :: 4 // 5 deg
# CDi: 0.0329
# Cl: 0.6341
#
# AR // AOA :: 6 // 5 deg
# CDi: 0.0283
# Cl: 0.7133
#
# AR // AOA :: 8 // 5 deg
# CDi: 0.0246
# Cl: 0.7617
#
# AR // AOA :: 10 // 5 deg
# CDi: 0.0218
# Cl: 0.7947

# %%
plt.figure()
AR, alphad = 4, 10
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 6, 10
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 8, 10
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

AR, alphad = 10, 10
n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

plt.title('Induced Angle of Attack')
plt.xlabel('theta [*]')
plt.ylabel('alpha_i [*]')
plt.grid()
plt.legend()
# Out:
# AR // AOA :: 4 // 10 deg
# CDi: 0.0796
# Cl: 0.9863
#
# AR // AOA :: 6 // 10 deg
# CDi: 0.0684
# Cl: 1.1095
#
# AR // AOA :: 8 // 10 deg
# CDi: 0.0596
# Cl: 1.1849
#
# AR // AOA :: 10 // 10 deg
# CDi: 0.0528
# Cl: 1.2363

# %%
# All combinations - Plotted in same window
plt.figure()
for i in [4,6, 8,10]:
    for j in [0, 5, 10]:
        AR, alphad = i, j
        n,theta,Cl,Cd,ai,An = planarWing(AR, alphad)
        plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR, alphad))
        print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))

#plt.legend()
# Out:
# AR // AOA :: 4 // 0 deg
# CDi: 0.0065
# Cl: 0.2818
#
# AR // AOA :: 4 // 5 deg
# CDi: 0.0329
# Cl: 0.6341
#
# AR // AOA :: 4 // 10 deg
# CDi: 0.0796
# Cl: 0.9863
#
# AR // AOA :: 6 // 0 deg
# CDi: 0.0056
# Cl: 0.3170
#
# AR // AOA :: 6 // 5 deg
# CDi: 0.0283
# Cl: 0.7133
#
# AR // AOA :: 6 // 10 deg
# CDi: 0.0684
# Cl: 1.1095
#
# AR // AOA :: 8 // 0 deg
# CDi: 0.0049
# Cl: 0.3386
#
# AR // AOA :: 8 // 5 deg
# CDi: 0.0246
# Cl: 0.7617
#
# AR // AOA :: 8 // 10 deg
# CDi: 0.0596
# Cl: 1.1849
#
# AR // AOA :: 10 // 0 deg
# CDi: 0.0043
# Cl: 0.3532
#
# AR // AOA :: 10 // 5 deg
# CDi: 0.0218
# Cl: 0.7947
#
# AR // AOA :: 10 // 10 deg
# CDi: 0.0528
# Cl: 1.2363

# %% [markdown]
# ### Part 2 - Elliptic
# Compute the induced angle of attack and induced drag coefficient for an elliptic wing with the same aspect ratios. Compare and discuss the solutions.

# %%
def ellipticWing(AR, alphad):
    alpha_L0 = -4.0

    # Induced lift and drag
    C_L = (2.0*np.pi/(1.0+2.0/AR))*(alphad*np.pi/180.0-alpha_L0*np.pi/180.0) 
    alpha_i = C_L/(np.pi*AR) * 180.0/np.pi
    C_D = C_L**2.0/(np.pi*AR)
    # Returns 'Induced Lift', 'Induced Drag', and 'induced AOA' in degrees.
    return C_L, C_D, alpha_i

# %%
# Print results for all combinations for the elliptic case.
for i in [4,6, 8,10]:
    for j in [0, 5, 10]:
        AR, alphad = i, j
        Cl,Cd,ai = ellipticWing(AR, alphad)
        print('\nAR // AOA :: {0:.0f} // {1:.0f} deg \nCDi: {2:.4f} \nCl: {3:.4f}'.format(AR, alphad, Cd, Cl))
        print('Induced angle: {0:.2f} deg'.format(ai))
# Out:
# AR // AOA :: 4 // 0 deg
# CDi: 0.0068
# Cl: 0.2924
# Induced angle: 1.33 deg
#
# AR // AOA :: 4 // 5 deg
# CDi: 0.0345
# Cl: 0.6580
# Induced angle: 3.00 deg
#
# AR // AOA :: 4 // 10 deg
# CDi: 0.0834
# Cl: 1.0235
# Induced angle: 4.67 deg
#
# AR // AOA :: 6 // 0 deg
# CDi: 0.0057
# Cl: 0.3290
# Induced angle: 1.00 deg
#
# AR // AOA :: 6 // 5 deg
# CDi: 0.0291
# Cl: 0.7402
# Induced angle: 2.25 deg
#
# AR // AOA :: 6 // 10 deg
# CDi: 0.0703
# Cl: 1.1515
# Induced angle: 3.50 deg
#
# AR // AOA :: 8 // 0 deg
# CDi: 0.0049
# Cl: 0.3509
# Induced angle: 0.80 deg
#
# AR // AOA :: 8 // 5 deg
# CDi: 0.0248
# Cl: 0.7896
# Induced angle: 1.80 deg
#
# AR // AOA :: 8 // 10 deg
# CDi: 0.0600
# Cl: 1.2282
# Induced angle: 2.80 deg
#
# AR // AOA :: 10 // 0 deg
# CDi: 0.0043
# Cl: 0.3655
# Induced angle: 0.67 deg
#
# AR // AOA :: 10 // 5 deg
# CDi: 0.0215
# Cl: 0.8225
# Induced angle: 1.50 deg
#
# AR // AOA :: 10 // 10 deg
# CDi: 0.0521
# Cl: 1.2794
# Induced angle: 2.33 deg

# %% [markdown]
# ### Part 3-5 (Tapered wing)

# %%
def taperedWing(AR, TR, alphad):
    m0 = 0.11*180/np.pi
    alpha = alphad *np.pi/180
    alpha_L0 = -4 *np.pi/180
    
    # number of sums 
    n_max = 20 # number of terms in sum
    n = np.linspace(1,n_max,n_max).astype(int)
    
    # number of equations (theta values)
    nEQ = n_max
    nEQ2 = int(nEQ+2)
    theta = np.linspace(np.pi/nEQ, np.pi-np.pi/nEQ, nEQ)
    #theta= theta[1: nEQ2-1]
    
    M = np.empty((nEQ, n_max)) # Empty matrix (100x100)
    b = np.empty( nEQ )
    c = np.empty( nEQ )
    Gamma = np.empty( nEQ )
    for i in range(nEQ):
        for j in range(n_max):
            # Calculate coefficients
            
            M[i,j] = np.sin(n[j]*theta[i])*(4*AR/(TR*m0) + n[j]/np.sin(theta[i])) 
        b[i] = alpha-alpha_L0 
        c[i] = 2*b[i]/(AR*(TR+1) * (1+(TR-1))*abs(np.cos(theta[i])))
        
    print c
    # Solve system
    An = np.linalg.solve(M,b)
    # Calculate induced angles
    alpha_i = np.empty(nEQ) # empty
    for i in range(nEQ):
        alpha_i[i] = sum(n*An*np.sin(n*theta[i])/np.sin(theta[i]))
    
    
    #Gamma calculation
    
    for i in range(nEQ):
        #c[i] = 2*b[i]/(AR(TR+1) * (1+(TR-1))*abs(cos(theta[i])))
            sum(An[i]*np.sin(n[i]*theta[i])* (2*AR*(T+1)/()))
        Gamma[i] = (AR*An[i]*np.sin(n[i]*theta[i]))/(1+TR)
    print Gamma
    
    
    
   
    
    
    # Induced lift and drag
    C_L = np.pi*AR * An[0] # eq. (8.51)
    C_D = np.pi*AR * np.sum(n*An**2) # eq. (8.52)
    return n, theta, C_L, C_D, alpha_i, An

# %%
def WingPlotTapered(AR, TR, alphad):

    for i in range(0,len(alphad)):
        plt.figure()
        for j in range(0,len(AR)):
            n,theta,Cl,Cd,ai,An = planarWing(AR[j],TR[k] alphad[i])
            plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}'.format(AR[j], alphad[i]))
            
        plt.title('Induced Angle of Attack')
        plt.xlabel('theta [deg]')
        plt.ylabel('alpha_i [deg]')
        plt.grid()
        plt.legend()
        name = 'tapered'+str(alphad[i]) +'.png'
        plt.savefig(name)
    plt.figure()
    
    
    
    '''
    for i in range(0,len(alphad)):
        for j in range(0,len(AR)):
            n, theta, Cl, Cd, ai, An = planarWing(AR[j], TR[k], alphad[i])
            plt.plot(theta*180/np.pi, ai*180/np.pi, label='AR: {0:.0f}, aoa: {1:.0f}*'.format(AR[j], alphad[i]))

        plt.title('Induced Angle of Attack for all AoA')
        plt.xlabel('theta [deg]')
        plt.ylabel('alpha_i [deg]')
        plt.grid()
        #plt.legend()
        name = 'AllInducedPlanar.png'
        plt.savefig(name)
    #plt.legend()
    '''

# %%
AR=[4, 6, 8, 10]
TR=1
alphad=[0, 5, 10, 15]

WingPlot(AR,TR,alphad)
# Out:
# [ 0.01767085  0.01830294  0.01942728  0.02119803  0.02390536  0.02811801
#   0.03507413  0.04801351  0.07884241  0.23478448  0.23478448  0.07884241
#   0.04801351  0.03507413  0.02811801  0.02390536  0.02119803  0.01942728
#   0.01830294  0.01767085]
# [  7.01633222e-03   0.00000000e+00   4.14336957e-03  -1.28911015e-19
#   -4.41747190e-04   2.02188123e-19   1.76724276e-04   6.78484132e-22
#   -3.01460592e-05   5.46005305e-20  -2.05973762e-05  -1.76427975e-19
#    1.77074846e-06  -2.42831784e-19   5.81433796e-06  -1.18374402e-19
#   -2.56318680e-06  -8.37843042e-20  -6.07913137e-07  -2.59737953e-34]
# [ 0.01178057  0.01220196  0.01295152  0.01413202  0.01593691  0.01874534
#   0.02338275  0.032009    0.05256161  0.15652299  0.15652299  0.05256161
#   0.032009    0.02338275  0.01874534  0.01593691  0.01413202  0.01295152
#   0.01220196  0.01178057]
# [  7.89258768e-03   1.61123660e-18   5.99857594e-03  -1.08492229e-19
#   -7.55475665e-04   9.47955712e-19   3.26929690e-04  -1.84035093e-21
#   -5.74147942e-05  -1.11997475e-19  -3.95812753e-05  -3.69577597e-20
#    3.40991118e-06  -2.39218571e-19   1.11986467e-05  -7.53169100e-21
#   -4.93735176e-06  -1.00288392e-19  -1.17220539e-06   1.38766163e-33]
# [ 0.00883543  0.00915147  0.00971364  0.01059902  0.01195268  0.01405901
#   0.01753707  0.02400675  0.03942121  0.11739224  0.11739224  0.03942121
#   0.02400675  0.01753707  0.01405901  0.01195268  0.01059902  0.00971364
#   0.00915147  0.00883543]
# [  8.42906638e-03   9.09789173e-19   7.49457852e-03   0.00000000e+00
#   -1.06287159e-03   9.07036130e-19   4.92122268e-04  -1.53659711e-20
#   -8.91900551e-05   1.47875312e-19  -6.22778126e-05  -2.44360189e-19
#    5.39069204e-06  -3.20006386e-19   1.77345404e-05  -1.63231629e-19
#   -7.82641161e-06  -9.74109092e-20  -1.86067562e-06  -1.18018246e-33]
# [ 0.00706834  0.00732118  0.00777091  0.00847921  0.00956214  0.0112472
#   0.01402965  0.0192054   0.03153696  0.09391379  0.09391379  0.03153696
#   0.0192054   0.01402965  0.0112472   0.00956214  0.00847921  0.00777091
#   0.00732118  0.00706834]
# [  8.79416539e-03   9.81103720e-19   8.71867333e-03  -1.14362479e-18
